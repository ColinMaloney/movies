# %%
import requests
from bs4 import BeautifulSoup
import re 
import pandas as pd 
import json
import time

# %%
url = 'https://www.the-numbers.com/weekly-box-office-chart'

# %%
data = requests.get(url)

# %%
data_set = BeautifulSoup(data.text, 'html.parser')

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

html = requests.get(url, headers=headers) # avoid the 403
weekly_df = pd.read_html(html.text)[1]
weekly_df.columns = list(df.iloc[0].values)

# %%
weekly_df.head()
# Out:
#    1  (1)              Angel Has Fallen      Lionsgate  $18,346,280  -37%  \
# 0  1  (1)              Angel Has Fallen      Lionsgate  $18,346,280  -37%
# 1  2  (2)                     Good Boys      Universal  $14,451,735  -13%
# 2  3  (3)                 The Lion King    Walt Disney  $10,684,145   -9%
# 3  4  (6)  Fast & Furious Presents: Ho…      Universal   $9,719,795  -14%
# 4  5  (4)                     Overcomer  Sony Pictures   $9,409,534  -19%
#
#    3336  $5,499   $47,460,501  2
# 0  3336  $5,499   $47,460,501  2
# 1  3458  $4,179   $61,459,700  3
# 2  3190  $3,349  $524,913,439  7
# 3  2972  $3,270  $160,532,145  5
# 4  1827  $5,150   $20,956,163  2

# %%
weekly_df.tail()
# Out:
#      1   (1)         Angel Has Fallen             Lionsgate $18,346,280  -37%  \
# 76  77  (86)  Christ Stopped at Eboli       Rialto Pictures        $678  +47%
# 77  78  (77)               Diamantino           Kino Lorber        $603  -63%
# 78  79  (73)                 Piranhas       Music Box Films        $303  -87%
# 79  80  (76)             The Mountain           Kino Lorber        $153  -92%
# 80  81   (-)                 Hesburgh  OâMalley Creadon …        $112   NaN
#
#     3336 $5,499 $47,460,501     2
# 76     1   $678     $75,839  2059
# 77     1   $603     $70,088    15
# 78     2   $152     $19,368     5
# 79     1   $153     $51,684     6
# 80     1   $112    $197,560    19

# %%
dates = pd.date_range(start='1/1/2019', periods=55, freq='W-FRI')
dates
# Out:
# DatetimeIndex(['2019-01-04', '2019-01-11', '2019-01-18', '2019-01-25',
#                '2019-02-01', '2019-02-08', '2019-02-15', '2019-02-22',
#                '2019-03-01', '2019-03-08', '2019-03-15', '2019-03-22',
#                '2019-03-29', '2019-04-05', '2019-04-12', '2019-04-19',
#                '2019-04-26', '2019-05-03', '2019-05-10', '2019-05-17',
#                '2019-05-24', '2019-05-31', '2019-06-07', '2019-06-14',
#                '2019-06-21', '2019-06-28', '2019-07-05', '2019-07-12',
#                '2019-07-19', '2019-07-26', '2019-08-02', '2019-08-09',
#                '2019-08-16', '2019-08-23', '2019-08-30', '2019-09-06',
#                '2019-09-13', '2019-09-20', '2019-09-27', '2019-10-04',
#                '2019-10-11', '2019-10-18', '2019-10-25', '2019-11-01',
#                '2019-11-08', '2019-11-15', '2019-11-22', '2019-11-29',
#                '2019-12-06', '2019-12-13', '2019-12-20', '2019-12-27',
#                '2020-01-03', '2020-01-10', '2020-01-17'],
#               dtype='datetime64[ns]', freq='W-FRI')

# %%
# num = 23 
# older_charts = 'https://www.the-numbers.com/box-office-chart/weekly/2019/08/{num}'

# %%
# df['week_from_loop'] = '2018/01/07'
df.head()


# dates[1].strftime('%Y/%m/%d') # datetime object to a string
# # .strptime (string to datetime object)

# # 2019/08/23
# dates_to_get = ["https://www.the-numbers.com/box-office-chart/weekly/" + 
#          x.strftime('%Y/%m/%d') for x in dates]

# %%
years = range(2009,2020)

# %%
for year in years:
    url = f'https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-{year}' 
    print(url)
# Out:
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2009
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2010
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2011
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2012
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2013
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2014
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2015
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2016
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2017
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2018
# https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-2019

# %%
url = f'https://www.the-numbers.com/box-office-records/worldwide/all-movies/cumulative/released-in-{year}'

# %%
year = 2019
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

html = requests.get(url, headers=headers) # avoid the 403
yearly_df = pd.read_html(html.text)[1]
yearly_df = pd.DataFrame(yearly_df)

# %%
yearly_df['year'] = year

# %%
yearly_df.dropna(inplace=True)

# %%
yearly_df
# Out:
#     Rank                                       Movie Worldwide Box Office  \
# 0      1                           Avengers: Endgame       $2,795,466,365
# 1      2                               The Lion King       $1,599,137,780
# 2      3                              Captain Marvel       $1,126,129,839
# 3      4                   Spider-Man: Far From Home       $1,123,844,202
# 4      5                                 Toy Story 4       $1,053,300,065
# 5      6                                     Aladdin       $1,037,186,103
# 6      7       Fast & Furious Presents: Hobbs & Shaw         $719,840,050
# 7      8                Ne Zha Zhi Mo Tong Xiang Shi         $704,974,163
# 9     10  How to Train Your Dragon: The Hidden World         $519,235,419
# 10    11                 PokÃ©mon: Detective Pikachu         $429,685,022
# 11    12                   The Secret Life of Pets 2         $425,211,217
# 12    13                         Alita: Battle Angel         $402,971,268
# 13    14              Godzilla: King of the Monsters         $383,299,915
# 14    15                                     Shazam!         $363,664,533
# 15    16                                       Dumbo         $347,866,307
# 17    18         John Wick: Chapter 3 â Parabellum         $319,014,703
# 18    19             Once Upon a Timeâ¦in Hollywood         $310,568,392
# 20    21                                          Us         $255,206,930
# 21    22                 Men in Black: International         $252,859,118
# 22    23                                Dark Phoenix         $246,356,895
# 23    24                                       Glass         $245,303,505
# 24    25                          Lie huo ying xiong         $243,880,757
# 25    26                        Annabelle Comes Home         $223,130,723
# 26    27           The LEGO Movie 2: The Second Part         $190,131,036
# 27    28                                   Rocketman         $189,469,652
# 28    29                             It: Chapter Two         $185,062,152
# 30    31                                 Escape Room         $155,313,078
# 31    32                                   Yesterday         $137,078,409
# 34    35                     The Curse of La Llorona         $121,661,395
# 35    36                               Geukhanjikeob         $120,341,426
# ..   ...                                         ...                  ...
# 54    55      Tyler Perryâs A Madea Family Funeral          $74,781,999
# 56    57                                       Crawl          $74,608,002
# 57    58                               What Men Want          $69,911,903
# 58    59                           A Dogâs Journey          $68,504,266
# 59    60                                   ek-si-teu          $65,716,150
# 60    61                          Happy Death Day 2U          $64,268,178
# 62    63                                Cold Pursuit          $62,599,159
# 64    65                                          MA          $60,523,669
# 66    67                                       After          $58,090,525
# 68    69                                   Long Shot          $52,608,163
# 71    72                                Breakthrough          $49,022,784
# 73    74                                      Little          $48,735,270
# 74    75              Zhui Long 2: Zhui Ji Da Fu Hao          $44,584,926
# 76    77                              Childâs Play          $43,504,393
# 77    78                                     Hellboy          $40,786,480
# 79    80                                Ready or Not          $39,012,480
# 80    81                     Fighting With My Family          $38,730,232
# 81    82                                The Intruder          $36,459,289
# 82    83                                   Midsommar          $35,368,150
# 85    86                                  BrightBurn          $32,626,338
# 86    87                                      Stuber          $29,634,769
# 87    88                     47 Meters Down: Uncaged          $29,105,478
# 90    91               The Art of Racing in the Rain          $28,732,714
# 91    92                                        Anna          $28,496,514
# 92    93                   The Kid Who Would Be King          $28,296,983
# 94    95                          No Manches Frida 2          $26,377,799
# 95    96                                   UglyDolls          $26,116,083
# 97    98                                    Akinjeon          $25,560,600
# 98    99                                   Overcomer          $25,125,005
# 99   100                                         Don          $24,945,222
#
#    Domestic Box Office International Box Office DomesticShare  year
# 0         $858,366,365           $1,937,100,000        30.71%  2019
# 1         $529,237,780           $1,069,900,000        33.10%  2019
# 2         $426,829,839             $699,300,000        37.90%  2019
# 3         $388,120,898             $735,723,304        34.54%  2019
# 4         $431,810,752             $621,489,313        41.00%  2019
# 5         $354,801,322             $682,384,781        34.21%  2019
# 6         $164,340,050             $555,500,000        22.83%  2019
# 7           $3,470,710             $701,503,453         0.49%  2019
# 9         $160,799,505             $358,435,914        30.97%  2019
# 10        $144,105,346             $285,579,676        33.54%  2019
# 11        $158,111,845             $267,099,372        37.18%  2019
# 12         $85,710,210             $317,261,058        21.27%  2019
# 13        $110,500,138             $272,799,777        28.83%  2019
# 14        $140,371,656             $223,292,877        38.60%  2019
# 15        $114,766,307             $233,100,000        32.99%  2019
# 17        $171,002,126             $148,012,577        53.60%  2019
# 18        $134,368,392             $176,200,000        43.27%  2019
# 20        $175,006,930              $80,200,000        68.57%  2019
# 21         $79,790,972             $173,068,146        31.56%  2019
# 22         $65,845,974             $180,510,921        26.73%  2019
# 23        $111,035,005             $134,268,500        45.26%  2019
# 24            $290,217             $243,590,540         0.12%  2019
# 25         $73,608,458             $149,522,265        32.99%  2019
# 26        $105,806,508              $84,324,528        55.65%  2019
# 27         $96,368,160              $93,101,492        50.86%  2019
# 28         $91,062,152              $94,000,000        49.21%  2019
# 30         $57,000,756              $98,312,322        36.70%  2019
# 31         $73,286,650              $63,791,759        53.46%  2019
# 34         $54,733,739              $66,927,656        44.99%  2019
# 35          $1,565,885             $118,775,541         1.30%  2019
# ..                 ...                      ...           ...   ...
# 54         $73,257,045               $1,524,954        97.96%  2019
# 56         $39,014,193              $35,593,809        52.29%  2019
# 57         $54,611,903              $15,300,000        78.12%  2019
# 58         $22,546,590              $45,957,676        32.91%  2019
# 59            $416,150              $65,300,000         0.63%  2019
# 60         $28,051,045              $36,217,133        43.65%  2019
# 62         $32,138,862              $30,460,297        51.34%  2019
# 64         $45,373,120              $15,150,549        74.97%  2019
# 66         $12,138,565              $45,951,960        20.90%  2019
# 68         $30,316,271              $22,291,892        57.63%  2019
# 71         $40,713,082               $8,309,702        83.05%  2019
# 73         $40,673,960               $8,061,310        83.46%  2019
# 74            $196,634              $44,388,292         0.44%  2019
# 76         $29,208,403              $14,295,990        67.14%  2019
# 77         $21,903,748              $18,882,732        53.70%  2019
# 79         $25,712,480              $13,300,000        65.91%  2019
# 80         $22,958,583              $15,771,649        59.28%  2019
# 81         $35,388,976               $1,070,313        97.06%  2019
# 82         $27,242,964               $8,125,186        77.03%  2019
# 85         $17,259,427              $15,366,911        52.90%  2019
# 86         $22,370,452               $7,264,317        75.49%  2019
# 87         $20,905,478               $8,200,000        71.83%  2019
# 90         $25,256,221               $3,476,493        87.90%  2019
# 91          $7,743,794              $20,752,720        27.17%  2019
# 92         $16,790,790              $11,506,193        59.34%  2019
# 94          $9,270,920              $17,106,879        35.15%  2019
# 95         $20,150,241               $5,965,842        77.16%  2019
# 97            $216,494              $25,344,106         0.85%  2019
# 98         $24,668,925                 $456,080        98.18%  2019
# 99            $155,732              $24,789,490         0.62%  2019
#
# [72 rows x 7 columns]

# %%
overall_df.append(yearly_df)
overall_df
# Out:
#     Rank                                        Movie Worldwide Box Office  \
# 0      1                       Avengers: Infinity War       $2,048,134,200
# 1      2                                Black Panther       $1,348,258,224
# 2      3               Jurassic World: Fallen Kingdom       $1,305,772,799
# 3      4                                Incredibles 2       $1,242,507,764
# 4      5                                      Aquaman       $1,146,894,640
# 5      6                            Bohemian Rhapsody         $893,017,661
# 6      7                                        Venom         $853,628,605
# 7      8                Mission: ImpossibleâFallout         $787,456,552
# 8      9                                   Deadpool 2         $786,680,557
# 9     10  Fantastic Beasts: The Crimes of Grindelwald         $652,220,086
# 10    11                         Ant-Man and the Wasp         $623,144,660
# 11    12                             Ready Player One         $579,290,136
# 12    13                           Hong Hai Xing Dong         $578,190,751
# 13    14                        Tang Ren Jie Tan An 2         $544,068,574
# 14    15                                      The Meg         $529,530,715
# 15    16        Hotel Transylvania 3: Summer Vacation         $527,060,998
# 16    17                    Ralph Breaks The Internet         $523,472,817
# 17    18                      Dr. Seussâ The Grinch         $510,978,677
# 18    19                                    Bumblebee         $465,195,589
# 20    21                               A Star is Born         $433,345,337
# 21    22                                      Rampage         $428,056,280
# 22    23                      Solo: A Star Wars Story         $393,151,347
# 23    24                 Mamma Mia: Here We Go Again!         $392,468,133
# 24    25         Spider-Man: Into The Spider-Verse 3D         $375,243,139
# 25    26                           Fifty Shades Freed         $371,350,619
# 27    28                                      The Nun         $363,676,447
# 28    29                                Zhuo yao ji 2         $361,683,815
# 29    30                                 Peter Rabbit         $347,132,280
# 30    31                         Mary Poppins Returns         $340,246,439
# 31    32                                A Quiet Place         $336,157,526
# ..   ...                                          ...                  ...
# 61    62                          Huang Qiang Zou Ban         $118,128,641
# 62    63                                   Game Night         $117,378,084
# 63    64                          Xi You Ji Nu Er Guo         $115,089,944
# 65    66                                    First Man         $105,213,813
# 66    67                                 Night School         $103,008,792
# 67    68                                 The Commuter         $101,985,431
# 68    69                                        Alpha          $99,624,873
# 69    70                               A Simple Favor          $97,628,717
# 71    72                                Truth or Dare          $95,127,344
# 73    74                                The Favourite          $94,069,024
# 74    75                                     Blockers          $94,045,328
# 75    76              Goosebumps 2: Haunted Halloween          $93,291,478
# 76    77                               BlacKkKlansman          $93,112,059
# 77    78                    Singwa Hamgge: Ingwa Yeon          $92,799,906
# 78    79                                I Feel Pretty          $91,553,797
# 79    80                                    Jing Zhou          $91,462,581
# 80    81                                    Book Club          $91,309,403
# 81    82               Di Ren Jie Zhi Si Da Tian Wang          $90,035,547
# 82    83                              Sherlock Gnomes          $87,527,651
# 84    85                           I Can Only Imagine          $85,642,586
# 85    86                                    Overboard          $85,369,830
# 86    87                               Mortal Engines          $85,287,417
# 88    89                                   Robin Hood          $84,747,441
# 89    90                                   Hereditary          $81,301,558
# 91    92                               Den of Thieves          $80,131,391
# 94    95                        The Spy Who Dumped Me          $77,109,957
# 95    96                                          Tag          $77,024,944
# 96    97                  Sicario: Day of the Soldado          $75,885,196
# 97    98                                    Searching          $75,371,276
# 99   100                                    Padmavati          $74,630,951
#
#    Domestic Box Office International Box Office DomesticShare  year
# 0         $678,815,482           $1,369,318,718        33.14%  2018
# 1         $700,059,566             $648,198,658        51.92%  2018
# 2         $417,719,760             $888,053,039        31.99%  2018
# 3         $608,581,744             $633,926,020        48.98%  2018
# 4         $335,061,807             $811,832,833        29.21%  2018
# 5         $216,303,339             $676,714,322        24.22%  2018
# 6         $213,511,408             $640,117,197        25.01%  2018
# 7         $220,159,104             $567,297,448        27.96%  2018
# 8         $324,591,735             $462,088,822        41.26%  2018
# 9         $159,555,901             $492,664,185        24.46%  2018
# 10        $216,648,740             $406,495,920        34.77%  2018
# 11        $137,690,172             $441,599,964        23.77%  2018
# 12          $1,543,547             $576,647,204         0.27%  2018
# 13          $1,983,984             $542,084,590         0.36%  2018
# 14        $145,443,742             $384,086,973        27.47%  2018
# 15        $167,500,092             $359,560,906        31.78%  2018
# 16        $201,091,711             $322,381,106        38.41%  2018
# 17        $270,620,950             $240,357,727        52.96%  2018
# 18        $127,195,589             $338,000,000        27.34%  2018
# 20        $215,288,866             $218,056,471        49.68%  2018
# 21        $101,028,233             $327,028,047        23.60%  2018
# 22        $213,767,512             $179,383,835        54.37%  2018
# 23        $120,634,935             $271,833,198        30.74%  2018
# 24        $190,173,195             $185,069,944        50.68%  2018
# 25        $100,407,760             $270,942,859        27.04%  2018
# 27        $117,450,119             $246,226,328        32.30%  2018
# 28            $706,153             $360,977,662         0.20%  2018
# 29        $115,234,093             $231,898,187        33.20%  2018
# 30        $171,958,438             $168,288,001        50.54%  2018
# 31        $188,024,361             $148,133,165        55.93%  2018
# ..                 ...                      ...           ...   ...
# 61            $551,196             $117,577,445         0.47%  2018
# 62         $69,179,066              $48,199,018        58.94%  2018
# 63            $187,074             $114,902,870         0.16%  2018
# 65         $44,936,545              $60,277,268        42.71%  2018
# 66         $77,339,130              $25,669,662        75.08%  2018
# 67         $36,343,858              $65,641,573        35.64%  2018
# 68         $35,851,379              $63,773,494        35.99%  2018
# 69         $53,548,586              $44,080,131        54.85%  2018
# 71         $41,411,015              $53,716,329        43.53%  2018
# 73         $34,366,783              $59,702,241        36.53%  2018
# 74         $60,311,495              $33,733,833        64.13%  2018
# 75         $46,697,321              $46,594,157        50.06%  2018
# 76         $49,275,340              $43,836,719        52.92%  2018
# 77          $1,200,246              $91,599,660         1.29%  2018
# 78         $48,795,601              $42,758,196        53.30%  2018
# 79            $521,396              $90,941,185         0.57%  2018
# 80         $68,566,296              $22,743,107        75.09%  2018
# 81            $262,963              $89,772,584         0.29%  2018
# 82         $43,242,871              $44,284,780        49.40%  2018
# 84         $83,482,352               $2,160,234        97.48%  2018
# 85         $50,316,123              $35,053,707        58.94%  2018
# 86         $15,951,040              $69,336,377        18.70%  2018
# 88         $30,824,628              $53,922,813        36.37%  2018
# 89         $44,069,456              $37,232,102        54.20%  2018
# 91         $44,947,622              $35,183,769        56.09%  2018
# 94         $33,562,069              $43,547,888        43.52%  2018
# 95         $54,730,625              $22,294,319        71.06%  2018
# 96         $50,065,850              $25,819,346        65.98%  2018
# 97         $26,015,149              $49,356,127        34.52%  2018
# 99         $11,846,060              $62,784,891        15.87%  2018
#
# [86 rows x 7 columns]

# %%
movies = yearly_df['Movie']
year_2016_list = []
for api_req in movies:
    movie_name = f"http://www.omdbapi.com/?t={api_req}&y={year}&apikey=b213361e"
    try:
        movie_ratings = requests.get(movie_name)
        year_2016_list.append(movie_ratings.text)
    except:
# Out:
# Captain America: Civil War
# Rogue One: A Star Wars Story
# Finding Dory
# Zootopia
# The Jungle Book
# The Secret Life of Pets
# Batman v Superman: Dawn of Justice
# Fantastic Beasts and Where to Find Them
# Deadpool
# Suicide Squad
# Doctor Strange
# Moana
# Sing
# Mei Ren Yu
# X-Men: Apocalypse
# Kung Fu Panda 3
# Warcraft
# La La Land
# Jason Bourne
# Ice Age: Collision Course
# Independence Day: Resurgence
# Kimi no na wa
# The Angry Birds Movie
# The Legend of Tarzan
# Trolls
# Star Trek Beyond
# The Great Wall
# Now You See Me 2
# Resident Evil: The Final Chapter
# The Conjuring 2: The Enfield Poltergeist
# Passengers
# Miss Peregrineâs Home for Peculiar Children
# Dangal
# Alice Through the Looking Glass
# Teenage Mutant Ninja Turtles: Out of the Shadows
# Assassinâs Creed
# Sully
# Hidden Figures
# Ghostbusters
# Inferno
# Central Intelligence
# Me Before You
# Bridget Jonesâs Baby
# Arrival
# The BFG
# London Has Fallen
# Xi You Ji zhi Sun Wu Kong San Da Bai Gu Jing
# Storks
# Bad Moms
# The Girl on the Train
# Operation Mekong
# The Divergent Series: Allegiant
# Hacksaw Ridge
# The Huntsman: Winterâs War
# The Magnificent Seven
# Jack Reacher: Never Go Back
# Donât Breathe
# The Accountant
# Lion
# Lights Out
# Sausage Party
# Gods of Egypt
# Peteâs Dragon
# Skiptrace
# Ride Along 2
# Deepwater Horizon
# I Belonged to You
# Allied
# The Shallows
# The Purge: Election Year
# Why Him?
# The 5th Wave
# Mechanic: Resurrection
# Neighbors 2: Sorority Rising
# 10 Cloverfield Lane
# Dirty Grandpa
# Cold War 2
# Railroad Tigers
# How to be Single
# Busanhaeng
# Ballerina
# Some Like It Hot
# Money Monster
# My Big Fat Greek Wedding 2
# Ben-Hur
# Office Christmas Party
# War Dogs
# Collateral Beauty
# Ouija: Origin of Evil
# Underworld: Blood Wars
# The Boss
# Manchester by the Sea
# Kubo and the Two Strings
# Mike and Dave Need Wedding Dates

# %%
movie_name = f"http://www.omdbapi.com/?t={api_req}&y={year}&apikey=b213361e"

# %%
movie_list =[]

# %%
movie_list.append(CACW_req.text)

# %%
movie_list
# Out:
# ['{"Title":"Captain America: Civil War","Year":"2016","Rated":"PG-13","Released":"06 May 2016","Runtime":"147 min","Genre":"Action, Adventure, Sci-Fi","Director":"Anthony Russo, Joe Russo","Writer":"Christopher Markus (screenplay by), Stephen McFeely (screenplay by), Joe Simon (based on the Marvel comics by), Jack Kirby (based on the Marvel comics by)","Actors":"Chris Evans, Robert Downey Jr., Scarlett Johansson, Sebastian Stan","Plot":"Political involvement in the Avengers\' affairs causes a rift between Captain America and Iron Man.","Language":"English, German, Xhosa, Russian, Romanian, Hindi","Country":"USA","Awards":"16 wins & 65 nominations.","Poster":"https://m.media-amazon.com/images/M/MV5BMjQ0MTgyNjAxMV5BMl5BanBnXkFtZTgwNjUzMDkyODE@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"7.8/10"},{"Source":"Rotten Tomatoes","Value":"91%"},{"Source":"Metacritic","Value":"75/100"}],"Metascore":"75","imdbRating":"7.8","imdbVotes":"597,664","imdbID":"tt3498820","Type":"movie","DVD":"13 Sep 2016","BoxOffice":"$408,080,554","Production":"Walt Disney Pictures","Website":"http://marvel.com/captainamerica#/home","Response":"True"}']
